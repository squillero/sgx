# %% [markdown]
# ```
#   _________ ____________  ___
#  /   _____//  _____/\   \/  /  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  \_____  \/   \  ___ \     /   THE E(X)TENDED (S)ELFISH (G)ENE ALGORITHM
#  /        \    \_\  \/     \   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /_________/\________/___/\  \  https://github.com/squillero/sgx
#                           \_/
# ```

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
import sys
sys.path += ['../src']
import logging
logging.basicConfig(format='%(asctime)s %(levelname)s: %(message)s', datefmt='%H:%M:%S')
logging.getLogger().setLevel(logging.INFO)
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
DB_NAME = 'one-max'

# %%
results = pd.read_sql_table(table_name='base', con=f'sqlite:///{DB_NAME}.sqlite3')

# %%
results
# Out:
#       index   Allele  Size  Learning Rate  Generations
# 0         0  Sigmoid    10          0.001           61
# 1         1  Sigmoid    10          0.001          102
# 2         2  Sigmoid    10          0.001           20
# 3         3  Sigmoid    10          0.001          575
# 4         4  Sigmoid    10          0.001           21
# ...     ...      ...   ...            ...          ...
# 5995   5995  Sigmoid    20          0.999         1501
# 5996   5996  Sigmoid    20          0.999         1464
# 5997   5997  Sigmoid    20          0.999         2057
# 5998   5998  Sigmoid    20          0.999         1541
# 5999   5999  Sigmoid    20          0.999         1892
#
# [6000 rows x 5 columns]

# %%
plt.figure(figsize=(16, 6))
sns.lineplot(data=results, x='Learning Rate', y='Generations', hue='Size')
# Out:
# <AxesSubplot:xlabel='Learning Rate', ylabel='Generations'>
